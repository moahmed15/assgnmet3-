# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
tt=pd.read_csv('train.csv')

# %%
tt.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
import seaborn as sns

# %%
sns.distplot(tt['Age'])
# Out:
# C:\Users\CST\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.pairplot(tt,hue='Sex',palette='rainbow')

# %%
import numpy as np
sns.barplot(x='Sex',y='Survived',data=tt,estimator=np.std)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
sns.barplot(x='Sex',y='Survived',data=tt,estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
sns.countplot(x='Sex',data=tt)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
tt.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(tt.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(tt.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
tt.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
tt['Survived'].dtype
# Out:
# dtype('int64')

# %%
sns.distplot(tt['Survived'])
# Out:
# C:\Users\CST\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Survived', ylabel='Density'>

# %%
import matplotlib.pyplot as plt

plt.rc('figure',figsize=(10,10))

df1=tt[tt['Survived']==0]['Age']
df2=tt[tt['Survived']==1]['Age']
plt.legend(('Died','Survived'),loc='best')
plt.title('survivors by age group')
plt.xlabel('Age')
plt.ylabel('Count')



plt.subplot(311)
plt.hist([df1,df2],bins=8,stacked=True)

plt.legend(('Died','Survived'),loc='best')
plt.title('survivors by age group (not filled)')
plt.ylabel('Count')


plt.legend(('Died','Survived'),loc='best')
plt.title('survivors by age group (filled)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
